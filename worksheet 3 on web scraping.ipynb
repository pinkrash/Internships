# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver=webdriver.Chrome()
driver.get('https://images.google.com/')
try:
    search_bar=driver.find_element(By.CLASS_NAME,"gLFyf")
    search_bar.send_keys('fruits')
    button=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span/svg/path')
    button.click()
    time.sleep(3)
except:
    print('not going on')
    
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    image.get_attribute('src')
    
    
    print("Top 10 images:", image)
    for url in image[:10]:
        print(url)
# Out:
# not going on

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com
# and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand
# Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver = webdriver.Chrome()
url="https://www.flipkart.com/search?q=smartphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
driver.get(url)

Brand_Name=[]
Storage=[]
PF_Camera=[]
Display_Size=[]
Processor=[]
Battery=[]
Price=[]


 
BName=driver.find_elements(By.XPATH,"//div[@class='_4rR01T']")
for i in BName:
    if i.text is None :
        Brand_Name.append("--") 
    else:
        Brand_Name.append(i.text)
print(Brand_Name)


ram=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[1]")
for i in ram:
    if i.text is None :
        Storage.append("--") 
    else:
        Storage.append(i.text)
print(Storage)


PC=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[3]")
for i in PC:
    if i.text is None :
        PF_Camera.append("--") 
    else:
        PF_Camera.append(i.text)
print(PF_Camera)


DS=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[2]")
for i in DS:
    if i.text is None :
        Display_Size.append("--") 
    else:
        Display_Size.append(i.text)
print(Display_Size)


P=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[5]")
for i in P:
    if i.text is None :
        Processor.append("--") 
    else:
        Processor.append(i.text)
print(ProcessorAndCores)


B=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[4]")
for i in B:
    if i.text is None :
        Battery.append("--") 
    else:
        Battery.append(i.text)
print(Battery)


price=driver.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']")
for i in price:
    if i.text is None :
        Price.append("--") 
    else:
        Price.append(i.text)
print(Price)

time.sleep(5)


print(len(Brand_Name),len(Storage),len(PF_Camera),len(Display_Size),len(Processor),len(Battery),len(Price))
# Out:
# ['POCO C51 (Royal Blue, 64 GB)', 'vivo T2x 5G (Aurora Gold, 128 GB)', 'vivo T2x 5G (Marine Blue, 128 GB)', 'vivo T2x 5G (Glimmer Black, 128 GB)', 'vivo T2x 5G (Marine Blue, 128 GB)', 'vivo T2x 5G (Marine Blue, 128 GB)', 'vivo T2x 5G (Glimmer Black, 128 GB)', 'vivo T2x 5G (Glimmer Black, 128 GB)', 'Motorola G34 5G (Ice Blue, 128 GB)', 'Motorola G34 5G (Ocean Green, 128 GB)', 'vivo T2 5G (Nitro Blaze, 128 GB)', 'Motorola G34 5G (Ocean Green, 128 GB)', 'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256 GB)', 'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)', 'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128 GB)', 'POCO C51 (Power Black, 64 GB)', 'POCO C55 (Forest Green, 64 GB)', 'POCO C55 (Cool Blue, 128 GB)', 'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)', 'POCO C55 (Power Black, 64 GB)', 'Motorola g54 5G (Pearl Blue, 128 GB)', 'REDMI 12 (Pastel Blue, 128 GB)', 'Apple iPhone 14 (Blue, 128 GB)', 'POCO C55 (Cool Blue, 64 GB)']
# ...

# %%
df=pd.DataFrame({"Brand name":Brand_Name,"Storage":Storage,"PF camera":PF_Camera,"Display size":Display_Size,"Processor":Processor,"Battery":Battery,"Price":Price[:24]})
df
# Out:
#                                            Brand name  \
# 0                        POCO C51 (Royal Blue, 64 GB)
# 1                   vivo T2x 5G (Aurora Gold, 128 GB)
# 2                   vivo T2x 5G (Marine Blue, 128 GB)
# 3                 vivo T2x 5G (Glimmer Black, 128 GB)
# 4                   vivo T2x 5G (Marine Blue, 128 GB)
# 5                   vivo T2x 5G (Marine Blue, 128 GB)
# 6                 vivo T2x 5G (Glimmer Black, 128 GB)
# 7                 vivo T2x 5G (Glimmer Black, 128 GB)
# 8                  Motorola G34 5G (Ice Blue, 128 GB)
# 9               Motorola G34 5G (Ocean Green, 128 GB)
# 10                   vivo T2 5G (Nitro Blaze, 128 GB)
# 11              Motorola G34 5G (Ocean Green, 128 GB)
# 12  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...
# 13    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)
# 14  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...
# 15                      POCO C51 (Power Black, 64 GB)
# ...

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver = webdriver.Chrome()
driver.get("https://www.digit.in/top-products/best-gaming-laptops")

Brands=[]
Images=[]
Price=[]

brand=driver.find_elements(By.XPATH,'//h3[@class=" text-clamp text-clamp-2"]')
for i in brand:
    Brands.append(i.text)
    
print(Brands)

image=driver.find_elements(By.XPATH,'//a[@class="img-centered-flex rh-flex-justify-center rh-flex-center-align"]')
for i in description:
    Images.append(i.get_attribute ('src'))

print(Images)

pri=driver.find_elements(By.XPATH,'//div[@class="cegg-price cegg-price-color cegg-price-instock"]')
for i in pri:
    Price.append(i.text)

print(Price)
# Out:
# []
# []
# ['Rs. 9,499', 'Rs. 14,990', 'Rs. 44,999', 'Rs. 59,999', 'Rs. 92,999']

# %% [markdown]
# # 7 Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped:
# “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
from bs4 import BeautifulSoup
import requests    
page = requests.get("https://www.forbes.com/billionaires/")
soup = BeautifulSoup(page.content)

soup
# Out:
# <!DOCTYPE html>
# ...

# %%
table=soup.find('table',class_="ng-scope ng-table")
rows = table.find_all('tr',class_="base ng-scope")
for row in rows:
    columns = row.find_all('td')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 table=soup.find('table',class_="ng-scope ng-table")
# ----> 2 rows = table.find_all('tr',class_="base ng-scope")
#       3 for row in rows:
#       4     columns = row.find_all('td')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
RANK=[]
columns = soup.find_elements('td',class_="name")
for i in columns:
    RANK.append(i.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[408], line 2
#       1 RANK=[]
# ----> 2 columns = soup.find_elements('td',class_="name")
#       3 for i in columns:
#       4     RANK.append(i.text)
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# # 8. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video.

# %%
driver=webdriver.Chrome()
driver.get('https://www.youtube.com/watch?v=pXwP1omHOGQ')

comment=[]
com=driver.find_elements(By.ID,'//div[@id="comment-content"]')
for i in com:
    comment.append(i.text)
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[411], line 5
#       2 driver.get('https://www.youtube.com/watch?v=pXwP1omHOGQ')
#       4 comment=[]
# ----> 5 com=driver.find_elements(By.ID,'//div[@id="comment-content"]')
#       6 for i in com:
#       7     comment.append(i.text)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:772, in WebDriver.find_elements(self, by, value)
#     768     value = f'[name="{value}"]'
#     770 # Return empty list if driver returns null
#     771 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 772 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
# ...

# %% [markdown]
# # 9 Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall
# reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome()
driver.get('https://www.hostelworld.com')
search=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/input')
search.send_keys('London,England')

button=soup.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button[1]/div/svg')
button.click()

# %%
NAME=[]
name=soup.find_elements(By.XPATH,'//div[@class="property-name"]/span')
for i in name:
    NAME.append(i.text)
    
DISTANCE=[]
dis=soup.find_elements(By.XPATH,'//span[@class="distance-description"]')
for i in dis:
    DISTANCE.append(i.text)
    
RATINGS=[]
rate=soup.find_elements(By.XPATH,'//span[@class="number"]')
for i in rate:
    RATINGS.append(i.text)
    
TOTAL_REVIEWS=[]
review=soup.find_elements(By.XPATH,'//div[@class="review"]/span')
for i in review:
    TOTAL_REVIEWS.append(i.text)
    
FACILITIES=[]
faci=soup.find_elements(By.XPATH,'//div[@class="icon-container badge-icon"]')
for i in faci:
    FACILITIES.append(i.text)
